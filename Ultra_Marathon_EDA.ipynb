# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
# Loading the dataset from a CSV file into a Pandas DataFrame
df = pd.read_csv('ultramarathon_data.csv')
# Display the first few rows of the dataframe to understand its structure
df.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12272\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7461195 entries, 0 to 7461194
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 740.0+ MB

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %% [markdown]
# ## CLean Up Data

# %% [markdown]
# ## Only want USA races, 50k or 50mi, 2020

# %%
# FOr 50K
df[df['Event distance/length']== '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# For 50K
df[df['Event distance/length']== '50k']
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
# For 50m
df[df['Event distance/length']== '50m']
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
# For 50mi
df[df['Event distance/length']== '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %% [markdown]
# ## Combine 50km and 50mi with isin

# %%
df[(df['Event distance/length'].isin(['50km','50mi']))]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']== 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']
# Out:
#          Year of event Event dates                          Event name  \
# 51923             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51924             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51925             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51926             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51927             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# ...                ...         ...                                 ...
# 6417091           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417092           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417093           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417094           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417095           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
usa_events = df[df['Event name'].str.contains("USA", na=False)]
usa_events
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# Combine all filters 
df_v2 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']== 2020) & (df['Event name'].str.contains("USA"))]

# %%
df_v2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %% [markdown]
# ## Working on Filtered data (df_v2)

# %%
# remove (USA) from event name
df_v2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26524, dtype: object

# %%
df_v2['Event name'] = df_v2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12272\1540751851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v2['Event name'] = df_v2['Event name'].str.split('(').str.get(0)

# %%
df_v2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %% [markdown]
# ## CLean up Athlete Age

# %%
df_v2['athlete_age'] = 2020 - df_v2['Athlete year of birth']
df_v2
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12272\1759942005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v2['athlete_age'] = 2020 - df_v2['Athlete year of birth']
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# ...

# %%
# remove 'h' from athlete performance

# %%
df_v2['Athlete performance'] = df_v2['Athlete performance'].str.split(' ').str.get(0)
df_v2
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12272\420960926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v2['Athlete performance'] = df_v2['Athlete performance'].str.split(' ').str.get(0)
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...

# %%
# drop columns : Athlete club, Athlete Country, Athlete year of birth, Athelete age category
df_v2 = df_v2.drop(['Athlete club','Athlete country','Athlete year of birth','Athlete age category'], axis =1)
df_v2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
# clean up null values

# %%
df_v2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  235
# dtype: int64

# %%
df_v2[df_v2['athlete_age'].isna()==1]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# drop these na
df_v2 = df_v2.dropna()
df_v2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
df_v2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athlete_age                  0
# dtype: int64

# %%
# check for duplicates
df_v2[df_v2.duplicated()== True]
df_v2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
# reset index 
df_v2 = df_v2.reset_index()
df_v2
# Out:
#          index  Year of event Event dates  \
# 0      2539945           2020  02.02.2020
# 1      2539946           2020  02.02.2020
# 2      2539947           2020  02.02.2020
# 3      2539948           2020  02.02.2020
# 4      2539949           2020  02.02.2020
# ...        ...            ...         ...
# 26284  2760957           2020  03.10.2020
# 26285  2760958           2020  03.10.2020
# 26286  2760959           2020  03.10.2020
# 26287  2760960           2020  03.10.2020
# 26288  2760961           2020  03.10.2020
#
#                                      Event name Event distance/length  \
# 0      West Seattle Beach Run - Winter Edition                   50km
# 1      West Seattle Beach Run - Winter Edition                   50km
# 2      West Seattle Beach Run - Winter Edition                   50km
# 3      West Seattle Beach Run - Winter Edition                   50km
# 4      West Seattle Beach Run - Winter Edition                   50km
# ...

# %%
# fix types
df_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26289 entries, 0 to 26288
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      26289 non-null  int64
#  1   Year of event              26289 non-null  int64
#  2   Event dates                26289 non-null  object
#  3   Event name                 26289 non-null  object
#  4   Event distance/length      26289 non-null  object
#  5   Event number of finishers  26289 non-null  int64
#  6   Athlete performance        26289 non-null  object
#  7   Athlete gender             26289 non-null  object
#  8   Athlete average speed      26289 non-null  object
#  9   Athlete ID                 26289 non-null  int64
#  10  athlete_age                26289 non-null  float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 2.2+ MB

# %%
# lets fix athlete_age
df_v2['athlete_age'] = df_v2['athlete_age'].astype(int)

# %%
df_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26289 entries, 0 to 26288
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      26289 non-null  int64
#  1   Year of event              26289 non-null  int64
#  2   Event dates                26289 non-null  object
#  3   Event name                 26289 non-null  object
#  4   Event distance/length      26289 non-null  object
#  5   Event number of finishers  26289 non-null  int64
#  6   Athlete performance        26289 non-null  object
#  7   Athlete gender             26289 non-null  object
#  8   Athlete average speed      26289 non-null  object
#  9   Athlete ID                 26289 non-null  int64
#  10  athlete_age                26289 non-null  int32
# dtypes: int32(1), int64(4), object(6)
# memory usage: 2.1+ MB

# %%
df_v2['Athlete average speed'] = df_v2['Athlete average speed'].astype(float)

# %%
df_v2.dtypes
# Out:
# index                          int64
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32
# dtype: object

# %%
# rename columns 
df_v2  = df_v2.rename(columns={
    'Year of event':'year',
    'Event dates': 'race_day',
    'Event name': 'race_name',
    'Event distance/length':'race_length',
    'Event number of finishers':'race_number_of_finishers',
    'Athlete performance' : 'athlete_performance',
    'Athlete gender': 'athlete_gender',
    'Athlete average speed':'athlete_average_speed',
    'Athlete ID': 'athlete_id'
    
})

# %%
df_v2
# Out:
#          index  year    race_day                                 race_name  \
# 0      2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1      2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2      2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3      2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4      2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...        ...   ...         ...                                       ...
# 26284  2760957  2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26285  2760958  2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26286  2760959  2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26287  2760960  2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26288  2760961  2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       race_length  race_number_of_finishers athlete_performance  \
# ...

# %%
df_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26289 entries, 0 to 26288
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     26289 non-null  int64
#  1   year                      26289 non-null  int64
#  2   race_day                  26289 non-null  object
#  3   race_name                 26289 non-null  object
#  4   race_length               26289 non-null  object
#  5   race_number_of_finishers  26289 non-null  int64
#  6   athlete_performance       26289 non-null  object
#  7   athlete_gender            26289 non-null  object
#  8   athlete_average_speed     26289 non-null  float64
#  9   athlete_id                26289 non-null  int64
#  10  athlete_age               26289 non-null  int32
# dtypes: float64(1), int32(1), int64(4), object(5)
# memory usage: 2.1+ MB

# %%
# reorder columns
df_v3 = df_v2[['race_day','race_name','race_length','race_number_of_finishers','athlete_id','athlete_gender','athlete_age','athlete_performance','athlete_average_speed']]

# %%
df_v3
# Out:
#          race_day                                 race_name race_length  \
# 0      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...           ...                                       ...         ...
# 26284  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26285  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26286  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26287  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 26288  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# ...

# %%
# find 2 races that ran in 2020 - manasota | everglades
df_v3[df_v3['race_name'] == 'Everglades 50 Mile Ultra Run ']
# Out:
#         race_day                      race_name race_length  \
# 7283  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7284  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7285  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7286  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7287  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7288  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7289  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7290  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7291  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7292  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7293  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7294  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7295  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7296  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7297  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# ...

# %%
# find for athlete id 222509
df_v3[df_v3['athlete_id'] == 222509]
# Out:
#          race_day                      race_name race_length  \
# 7289   14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 11256  22.02.2020       Manasota Track Club 50K         50km
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 7289                         40      222509              M           23
# 11256                        36      222509              M           23
#
#       athlete_performance  athlete_average_speed
# 7289              9:19:10                  8.634
# 11256             4:49:16                 10.371

# %% [markdown]
# ## Charts and Graphs

# %%
sns.histplot(df_v3['race_length'])
# Out:
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
palette_colors = {"M": "blue", "F": "red"}

# Create the histogram plot with specified colors
sns.histplot(data=df_v3, x='race_length', hue='athlete_gender', palette=palette_colors)
# Out:
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.histplot(df_v3, x = 'race_length', hue='athlete_gender')
# Out:
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# average speed for 50mi
sns.displot(df_v3[df_v3['race_length'] == '50mi']['athlete_average_speed'])
# Out:
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# average speed for 50km
sns.displot(df_v3[df_v3['race_length'] == '50km']['athlete_average_speed'])
# Out:
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.violinplot(data = df_v3, x='race_length', y ='athlete_average_speed', hue='athlete_gender',split = True)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data = df_v3, x='athlete_age', y ='athlete_average_speed', hue='athlete_gender')

# %% [markdown]
# ## Questions I want to find out from the data

# %%
# Difference in speed 50k, 50mi male to female
df_v3.groupby(['race_length','athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 7.092015
#              M                 7.743376
# 50mi         F                 6.830764
#              M                 7.249766
# Name: athlete_average_speed, dtype: float64

# %%
# what age groups are the best in the 50mi race (20 + races min)
df_v3.query('race_length=="50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 29           7.895574    136
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.471053     95
# 31           7.440842    139
# 38           7.420884    232
# 35           7.414633    196
# 36           7.394645    186
# 33           7.379188    149
# 22           7.367902     41
# 26           7.328584     77
# 42           7.327656    209
# 24           7.327203     74
# 34           7.307923    183
# 21           7.304658     38
# 40           7.304553    237
# 20           7.293778     27
# 39           7.283566    228
# 32           7.269518    164
# 37           7.220493    221
# 27           7.201748    119
# 41           7.185767    180
# 45           7.130667    156
# 47           7.085410    156
# 44           7.047361    180
# 51           7.014248    125
# 46           6.900326    175
# 43           6.874670    188
# 52           6.847400    130
# ...

# %%
# what age groups are the worst in the 50mi race (20 + races min)
df_v3.query('race_length=="50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = True).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 60           6.227206     34
# 62           6.267564     39
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67
# 64           6.620727     22
# 50           6.671541    172
# 59           6.672072     83
# 48           6.696853    136
# 56           6.708373     67
# 53           6.724598     97
# 57           6.783205     78
# 49           6.789776    161
# 54           6.792429     84
# 55           6.814800     70
# 52           6.847400    130
# 43           6.874670    188
# 46           6.900326    175
# 51           7.014248    125
# 44           7.047361    180
# 47           7.085410    156
# 45           7.130667    156
# 41           7.185767    180
# 27           7.201748    119
# 37           7.220493    221
# 32           7.269518    164
# 39           7.283566    228
# 20           7.293778     27
# 40           7.304553    237
# 21           7.304658     38
# ...

# %%
# what age groups are the best in the 50km race (20 + races min)
df_v3.query('race_length=="50km"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 20           8.712523     86
# 22           8.252475    120
# 21           8.129901     91
# 26           8.109766    312
# 19           8.066386     44
# 23           8.060486    179
# 27           8.049621    330
# 24           8.005956    204
# 32           7.999102    549
# 29           7.974724    450
# 28           7.971808    427
# 25           7.947700    283
# 30           7.911649    456
# 18           7.846559     34
# 36           7.841935    647
# 35           7.836588    609
# 31           7.828258    472
# 33           7.807963    517
# 37           7.777378    733
# 34           7.773293    577
# 38           7.685738    810
# 39           7.666726    810
# 42           7.665652    706
# 40           7.631972    780
# 41           7.542676    694
# 16           7.537150     20
# 43           7.478202    703
# 44           7.466072    663
# 48           7.427770    565
# 51           7.391711    540
# ...

# %%
# what age groups are the worst in the 50km race (20 + races min)
df_v3.query('race_length=="50km"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = True).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 71           6.072625     40
# 70           6.174400     20
# 69           6.174658     38
# 73           6.337682     22
# 67           6.355094     53
# 68           6.379146     48
# 65           6.487299     77
# 66           6.494935     77
# 63           6.648798    119
# 61           6.726805    190
# 64           6.828880    117
# 62           6.871537    160
# 60           6.894801    211
# 57           6.925599    329
# 58           6.944760    250
# 59           6.965196    270
# 50           7.118916    618
# 52           7.160221    497
# 53           7.189837    404
# 54           7.190416    404
# 45           7.271481    643
# 49           7.284732    575
# 56           7.289608    314
# 47           7.300150    605
# 46           7.315760    684
# 55           7.327604    341
# 17           7.344808     26
# 51           7.391711    540
# 48           7.427770    565
# 44           7.466072    663
# ...

# %%
df_v3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26289 entries, 0 to 26288
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   race_day                  26289 non-null  object
#  1   race_name                 26289 non-null  object
#  2   race_length               26289 non-null  object
#  3   race_number_of_finishers  26289 non-null  int64
#  4   athlete_id                26289 non-null  int64
#  5   athlete_gender            26289 non-null  object
#  6   athlete_age               26289 non-null  int32
#  7   athlete_performance       26289 non-null  object
#  8   athlete_average_speed     26289 non-null  float64
# dtypes: float64(1), int32(1), int64(2), object(5)
# memory usage: 1.7+ MB

# %%
# Seasons for the data - Slower in summer than winter?
#spring 3-5
#summer 6-8
#fall 9-11
#winter 12-2

# %%
df_v3['race_month'] = df_v3['race_day'].str.split('.').str.get(1).astype(int)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12272\188773694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v3['race_month'] = df_v3['race_day'].str.split('.').str.get(1).astype(int)

# %%
df_v3.head()
# Out:
#      race_day                                 race_name race_length  \
# 0  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#    race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 0                        20       71287              M           29
# 1                        20      629508              M           39
# 2                        20       64838              M           21
# 3                        20      704450              M           37
# 4                        20      810281              M           43
#
#   athlete_performance  athlete_average_speed  race_month
# 0             3:17:55                 15.158           2
# ...

# %%
df_v3['race_season'] = df_v3['race_month'].apply(lambda x: 'Winter' if x>11 else 'Fall' if x>8 else 'Summer' if x>5 else 'Spring' if x>2 else 'Winter')

# %%
df_v3.head(10)
# Out:
#      race_day                                 race_name race_length  \
# 0  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 5  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 6  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 7  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 8  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 9  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#    race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 0                        20       71287              M           29
# 1                        20      629508              M           39
# ...

# %%
values = df_v3['race_season'].value_counts()
print(values)
# Out:
# race_season
# Winter    11825
# Fall       8315
# Spring     3385
# Summer     2764
# Name: count, dtype: int64

# %%
df_v3.groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending= False)
# Out:
#                  mean  count
# race_season
# Spring       7.703542   3385
# Winter       7.524506  11825
# Fall         7.406619   8315
# Summer       6.859274   2764

# %%
# 50 miler only
df_v3.query('race_length =="50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending= False)
# Out:
#                  mean  count
# race_season
# Fall         7.511585   1997
# Spring       7.082557    836
# Winter       7.046989   1981
# Summer       6.486055    843

# %%
# 50 km only
df_v3.query('race_length =="50km"').groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending= False)
# Out:
#                  mean  count
# race_season
# Spring       7.907208   2549
# Winter       7.620601   9844
# Fall         7.373441   6318
# Summer       7.023056   1921
